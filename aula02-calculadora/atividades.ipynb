# %%
# Atividades

# %% [markdown]
# Qual é o resultado final das seguintes contas?

# %% [markdown]
# $6 \div 2(1 + 2)$

# %%
6 / 2 * (1 + 2)
# Out:
# 9.0

# %% [markdown]
# $48 - 3(16 + 15 \div 5 \times 3 - 2 \times 3) + 8$

# %%
48 - 3 * (16 + 15 / 5 * 3 - 2 * 3) + 8
# Out:
# -1.0

# %% [markdown]
# $7 + [(25 - 1) \div (3^2 - 3)] - 3$

# %%
7 + (25 - 1) / (3 ** 2 - 3) - 3
# Out:
# 8.0

# %% [markdown]
# $[12 - 36 \div (4^2 - 4) \div 3 + 2)] \times 5$

# %%
(12 - 36 / (4 ** 2 - 4) / 3 + 2) * 5
# Out:
# 65.0
