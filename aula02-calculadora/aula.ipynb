# %% [markdown]
# # Utilizando Python como uma calculadora científica

# %%
print("Hello World¹")   # este é um comentário que não será executado
# Out:
# Hello World¹

# %% [markdown]
# ## Tipos de variáveis numéricas
# x = 8 / 4 + 5 * (3 + 1) - 7 % 4

# %% [markdown]
# ### Inteiros

# %%
5
# Out:
# 5

# %%
type(5)
# Out:
# int

# %% [markdown]
# ### Floats

# %%
5.0
# Out:
# 5.0

# %%
type(5.0)
# Out:
# float

# %% [markdown]
# ### Conversão e arredondamento

# %%
int(6.32)
# Out:
# 6

# %%
round(6.32)     # não deixa nenhuma casa decimal
# Out:
# 6

# %%
round(6.32,1)   # deixa 1 casa decimal
# Out:
# 6.3

# %% [markdown]
# ### Complexos

# %%
c = complex(1, 2)

# %%
type(c)
# Out:
# complex

# %%
c
# Out:
# (1+2j)

# %%
c.real
# Out:
# 1.0

# %%
c.imag
# Out:
# 2.0

# %% [markdown]
# ## Quatro operações básicas

# %% [markdown]
# ### Soma
#
# $a+b$

# %%
1 + 1
# Out:
# 2

# %% [markdown]
# ### Subtração
#
# $a-b$

# %%
9 - 7
# Out:
# 2

# %% [markdown]
# ### Multiplicação
#
# $a \times b$

# %%
6 * 5
# Out:
# 30

# %% [markdown]
# ### Divisão
#
# $\ a \div b$ ou $\frac{a}{b}$

# %%
90 / 9
# Out:
# 10.0

# %% [markdown]
# ### Quociente e resto

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print(10 / 3)
# Out:
# 3.3333333333333335

# %% [markdown]
# ### Floor division (divisão inteira)
#
# Retorna o quociente inteiro mais próximo da divisão, arredondando para baixo

# %%
print(10 // 3)
# Out:
# 3

# %% [markdown]
# ### Modulus
#
# Retorna o resto da divisão

# %%
print(10 % 3) #modulus
# Out:
# 1

# %% [markdown]
# ### Exponenciação
#
# $a^b$

# %% [markdown]
# $5^2$

# %%
print(5 ** 2)
# Out:
# 25

# %% [markdown]
# $2^4$

# %%
print(2 ** 4)
# Out:
# 16

# %% [markdown]
# $16^{0.5}$

# %%
print(16 ** (0.5))
# Out:
# 4.0

# %% [markdown]
# $16^{-1}$
#
# expoente negativo: inverte a base e troca o sinal do expoente para negativo
# $a^{-n}$ = $\frac{1}{a^n}$

# %%
16 ** (-1)
# Out:
# 0.0625

# %% [markdown]
#  $\frac{1}{16}$

# %%
1/16
# Out:
# 0.0625

# %% [markdown]
# ### Raiz quadrada

# %%
import math
math.sqrt(16)
# Out:
# 4.0

# %%
from math import *

# Você pode diretamente utilizar as funções e constantes
print(sqrt(16))
print(pi)
# Out:
# 4.0
# 3.141592653589793

# %%
import numpy as np
np.sqrt(16)
# Out:
# np.float64(4.0)

# %%
from numpy import *
np.sqrt(16)
# Out:
# np.float64(4.0)

# %% [markdown]
# A última importação sobrescreve a anterior no namespace atual.

# %%
print(sqrt is math.sqrt)
print(sqrt is np.sqrt)
# Out:
# False
# True

# %%
print(type(sqrt))
# Out:
# <class 'numpy.ufunc'>

# %% [markdown]
# ### Ordem das operações - Ver Slides

# %%
x = 8 / 4 + 5 * (3 + 1) - 7 % 4
print(x)
# Out:
# 19.0

# %% [markdown]
# ### Constantes

# %%
#pi
print(pi)
# Out:
# 3.141592653589793

# %%
import numpy

# %%
numpy.pi
# Out:
# 3.141592653589793

# %%
numpy.e
# Out:
# 2.718281828459045

# %% [markdown]
# ### Erros comuns

# %%
numpy.sqrt(-1)
# Out:
# C:\Users\paula\AppData\Local\Temp\ipykernel_18696\1251204748.py:1: RuntimeWarning: invalid value encountered in sqrt
#   numpy.sqrt(-1)
# np.float64(nan)

# %%
numpy.divide(0,0)
# Out:
# C:\Users\paula\AppData\Local\Temp\ipykernel_18696\1272379990.py:1: RuntimeWarning: invalid value encountered in divide
#   numpy.divide(0,0)
# np.float64(nan)

# %%
type(numpy.array([1,]))
# Out:
# numpy.ndarray

# %%
numpy.array([1]) / 0.
# Out:
# C:\Users\paula\AppData\Local\Temp\ipykernel_18696\3275555932.py:1: RuntimeWarning: divide by zero encountered in divide
#   numpy.array([1]) / 0.
# array([inf])

# %%
numpy.log([-1])
# Out:
# C:\Users\paula\AppData\Local\Temp\ipykernel_18696\170367896.py:1: RuntimeWarning: invalid value encountered in log
#   numpy.log([-1])
# array([nan])
